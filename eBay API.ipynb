# %%
import os
import sys
from optparse import OptionParser
import ebaysdk

# %%
from ebaysdk.finding import Connection as Finding

api = Finding(appid="PayPal578-e6b6-421c-b72f-ce35d5802b2", config_file=None)
api_request = {
            'itemFilter': [
                {'name': 'Seller',
                 'value': 'twomysterybox'},
                {'name' : 'Seller',
                 'value' : 'tradephone2015'}
            ], 
                'paginationInput': {
                    'entriesPerPage': '25',
                    'pageNumber': '1'
                },
        }
response = api.execute('findItemsAdvanced', api_request)
print(response.dict())
# Out:
# {'ack': 'Failure', 'timestamp': '2016-01-07T20:56:20.746Z', 'errorMessage': {'error': {'category': 'Request', 'domain': 'Marketplace', 'severity': 'Error', 'message': 'Item filter SELLER can be used only one time in a request.', 'subdomain': 'Search', 'parameter': 'SELLER', 'errorId': '47'}}, 'version': '1.13.0'}

# %%
from ebaysdk.finding import Connection as Finding

api = Finding(appid="PayPal578-e6b6-421c-b72f-ce35d5802b2", config_file=None)
api_request = {
            'itemFilter': [
                {'name': 'Seller',
                 'value': 'twomysterybox'},
            ], 
                'paginationInput': {
                    'entriesPerPage': '25',
                    'pageNumber': '1'
                },
        }
response = api.execute('findItemsAdvanced', api_request)
print(response.dict())
# Out:
# {'itemSearchURL': 'http://www.ebay.com/sch/i.html?_sasl=twomysterybox&_saslop=1&_fss=1&LH_SpecificSeller=1&_ddo=1&_ipg=25&_pgn=1', 'paginationOutput': {'totalPages': '85', 'entriesPerPage': '25', 'pageNumber': '1', 'totalEntries': '2106'}, 'ack': 'Success', 'timestamp': '2016-01-07T20:56:34.019Z', 'searchResult': {'item': [{'itemId': '272073535313', 'topRatedListing': 'false', 'globalId': 'EBAY-US', 'title': "Khaki Fox Slippers - Women's US Size 9 womens slippers cute slippers 2016 new", 'country': 'KR', 'primaryCategory': {'categoryId': '11632', 'categoryName': 'Slippers'}, 'autoPay': 'true', 'galleryURL': 'http://thumbs2.ebaystatic.com/m/mcQaiTz3T-Zh7B40fNhphdQ/140.jpg', 'shippingInfo': {'expeditedShipping': 'false', 'shipToLocations': 'Worldwide', 'shippingServiceCost': {'_currencyId': 'USD', 'value': '4.0'}, 'oneDayShippingAvailable': 'false', 'handlingTime': '1', 'shippingType': 'Flat'}, 'location': 'Korea, South', 'returnsAccepted': 'true', 'viewItemURL': 'http://www.ebay.com/i
# ...

# %%
from ebaysdk.finding import Connection as Finding

api = Finding(appid="PayPal578-e6b6-421c-b72f-ce35d5802b2", config_file=None)
api_request = {
                'categoryId' : '9355', 
                'paginationInput': {
                    'entriesPerPage': '25',
                    'pageNumber': '1'
                },
        }
response = api.execute('findItemsAdvanced', api_request)
print(response.dict())
# Out:
# {'itemSearchURL': 'http://www.ebay.com/sch/9355/i.html?_ddo=1&_ipg=25&_pgn=1', 'paginationOutput': {'totalPages': '8524', 'entriesPerPage': '25', 'pageNumber': '1', 'totalEntries': '213098'}, 'ack': 'Success', 'timestamp': '2016-01-11T16:56:11.360Z', 'searchResult': {'item': [{'itemId': '151510242510', 'topRatedListing': 'false', 'productId': {'_type': 'ReferenceID', 'value': '144401118'}, 'globalId': 'EBAY-US', 'title': 'New Samsung Galaxy S 4 GT-I9500 16GB White Unlocked Android Smartphone 13MP', 'country': 'HK', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'autoPay': 'true', 'galleryURL': 'http://thumbs3.ebaystatic.com/m/mNXE7uP4_TkV1u07W9mmYfw/140.jpg', 'shippingInfo': {'expeditedShipping': 'false', 'shipToLocations': 'Worldwide', 'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'oneDayShippingAvailable': 'false', 'handlingTime': '3', 'shippingType': 'Free'}, 'location': 'Hong Kong', 'returnsAccepted': 'true', 'viewItemURL'
# ...

# %%
from ebaysdk.finding import Connection as Finding

api = Finding(appid="PayPal578-e6b6-421c-b72f-ce35d5802b2", config_file=None)
api_request = {
                'categoryId' : '9355', 
                'paginationInput': {
                    'entriesPerPage': '25',
                    'pageNumber': '1'
                },
                'outputSelector' : 'SellerInfo'
        }
response = api.execute('findItemsAdvanced', api_request)
print(response.dict())
# Out:
# {'itemSearchURL': 'http://www.ebay.com/sch/9355/i.html?_ddo=1&_ipg=25&_os=S%7CD&_pgn=1', 'paginationOutput': {'totalPages': '8604', 'entriesPerPage': '25', 'pageNumber': '1', 'totalEntries': '215091'}, 'ack': 'Success', 'timestamp': '2016-01-13T11:05:18.098Z', 'searchResult': {'item': [{'itemId': '111793358054', 'subtitle': 'COMES IN ORIGINAL RETAIL BOX W/ OEM ACCESSORIES', 'productId': {'_type': 'ReferenceID', 'value': '182515113'}, 'globalId': 'EBAY-US', 'title': 'Samsung Galaxy S5 SM-G900A - 16GB - White UNLOCKED GSM Smartphone AT&T TMOBILE', 'country': 'US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'autoPay': 'true', 'galleryURL': 'http://thumbs3.ebaystatic.com/m/mWABYpxN_2kF6IjwECBlakw/140.jpg', 'sellerInfo': {'feedbackRatingStar': 'TurquoiseShooting', 'feedbackScore': '28203', 'positiveFeedbackPercent': '99.6', 'topRatedSeller': 'true', 'sellerUserName': 'gadget.wizard'}, 'shippingInfo': {'expeditedShipping': 'true', 'shipToLocatio
# ...
